# %%
import ind_ec_data_scrapper as sc

# %%
sc.load_to_databricks("bihar_election_results_2026-04-14 19:35:40.csv", "data/bihar_election_results_2026-04-14 19:35:40.csv")
# Out:
# 204

# %%
df = sc.get_coalition_parties()
df.head()
# Out:
#                               party coalition
# 0               Janata Dal (United)       NDA
# 1            Bharatiya Janata Party       NDA
# 2   Lok Janshakti Party (Ram Vilas)       NDA
# 3  Hindustani Awam Morcha (Secular)       NDA
# 4              Rashtriya Lok Morcha       NDA

# %%
df = sc.get_state_result("Bihar", 2025)
df.head()
# Out:
# Scraping data for constituency number 1...
# Scraping data for constituency number 2...
# Scraping data for constituency number 3...
# Scraping data for constituency number 4...
# Scraping data for constituency number 5...
# Scraping data for constituency number 6...
# Scraping data for constituency number 7...
# Scraping data for constituency number 8...
# Scraping data for constituency number 9...
# Scraping data for constituency number 10...
# Scraping data for constituency number 11...
# Scraping data for constituency number 12...
# Scraping data for constituency number 13...
# Scraping data for constituency number 14...
# Scraping data for constituency number 15...
# Scraping data for constituency number 16...
# Scraping data for constituency number 17...
# Scraping data for constituency number 18...
# Scraping data for constituency number 19...
# Scraping data for constituency number 20...
# Scraping data for constituency number 21...
# ...
